# %%
from pymatgen.ext.matproj import MPRester
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
from jupyter_jsmol.pymatgen import quick_view
from pymatgen.core.operations import SymmOp
import matplotlib.pyplot as plt
from matplotlib.image import imread
from IPython.display import Image
import matplotlib.image as img

# %%
with MPRester("anJWfQsT0ZKuEBip") as m:
    # Structure for material id
    struct = m.get_structure_by_material_id("mp-961661")

# Opérations de symétrie
structu = SpacegroupAnalyzer(struct)
struct_conv = structu.get_conventional_standard_structure()
analyzer = SpacegroupAnalyzer(struct_conv).get_symmetry_operations()

# %%
# Axe 4-barre | centre d'inversion en (0,0,0)  (y,-x,-z)
Sym1 = analyzer[1]
# Plan miroir (z,y,x)
Sym2 = analyzer[5]
# Axe de rotation C2 (x,-y,-z)
Sym3 = analyzer[4]

#Coordonnées de 3 atomes dans la maille conventionnelle 
Zr = sites[2].frac_coords
Si = sites[4].frac_coords
Pd = sites[8].frac_coords

#Applications des opérations de symmétrie
ZrSym = Sym1.operate(Zr)
SiSym = Sym2.operate(Si)
PdSym = Sym3.operate(Pd)

# %% [markdown]
# # Première symétrie sur l'atome de Zr

# %%
print("Première opération de symétrie")
print("------------------------------")
print(" ")
print("Position de départ de l'atome Zr :", Zr )
print(" ")
print("On lui applique une symétrie d'axe 4-barre avec un centre d'inversion en (0,0,0) : ")
print(Sym1)
print(" ")
print("Position de l'atome Zr après l'opération de symétrie :", ZrSym)
print(" ")
print("Image :")

image_1=img.imread('Zr.png')
fig, axes = plt.subplots(figsize=(10,10))
axes.get_xaxis().set_visible(False)
axes.get_yaxis().set_visible(False)
axes.imshow(image_1)
plt.show()
# Out:
# Première opération de symétrie
# ------------------------------
#
# Position de départ de l'atome Zr : [0.  0.  0.5]
#
# On lui applique une symétrie d'axe 4-barre avec un centre d'inversion en (0,0,0) :
# Rot:
# [[ 0.  1.  0.]
#  [-1.  0.  0.]
#  [ 0.  0. -1.]]
# tau
# [0. 0. 0.]
#
# Position de l'atome Zr après l'opération de symétrie : [ 0.   0.  -0.5]
#
# Image :

# %% [markdown]
# # Deuxième symétrie sur l'atome de Si

# %%
print("Deuxième opération de symétrie")
print("------------------------------")
print(" ")
print("Position de départ de l'atome Si :", Si )
print(" ")
print("On lui applique une symétrie de plan miroir (y,x,z) :")
print(Sym2)
print(" ")
print("Position de l'atome Si après l'opération de symétrie :", SiSym)
print(" ")
print("Image :")

image_1=img.imread('Si.png')
fig, axes = plt.subplots(figsize=(10,10))
axes.get_xaxis().set_visible(False)
axes.get_yaxis().set_visible(False)
axes.imshow(image_1)
plt.show()
# Out:
# Deuxième opération de symétrie
# ------------------------------
#
# Position de départ de l'atome Si : [0. 0. 0.]
#
# On lui applique une symétrie de plan miroir (y,x,z) :
# Rot:
# [[0. 1. 0.]
#  [1. 0. 0.]
#  [0. 0. 1.]]
# tau
# [0. 0. 0.]
#
# Position de l'atome Si après l'opération de symétrie : [0. 0. 0.]
#
# Image :

# %% [markdown]
# # Troisième symétrie sur l'atome de Pd

# %%
print("Troisième opération de symétrie")
print("------------------------------")
print(" ")
print("Position de départ de l'atome Pd:", Pd )
print(" ")
print("On lui applique une symétrie d'axe C2 (x,-y,-z) : ")
print(Sym3)
print(" ")
print("Position de l'atome Pd après l'opération de symétrie :", PdSym)
print(" ")
print("Image :")

image_1=img.imread('Pd.png')
fig, axes = plt.subplots(figsize=(10,10))
axes.get_xaxis().set_visible(False)
axes.get_yaxis().set_visible(False)
axes.imshow(image_1)
plt.show()
# Out:
# Troisième opération de symétrie
# ------------------------------
#
# Position de départ de l'atome Pd: [0.25 0.25 0.25]
#
# On lui applique une symétrie d'axe C2 (x,-y,-z) :
# Rot:
# [[ 1.  0.  0.]
#  [ 0. -1.  0.]
#  [ 0.  0. -1.]]
# tau
# [0. 0. 0.]
#
# Position de l'atome Pd après l'opération de symétrie : [ 0.25 -0.25 -0.25]
#
# Image :
